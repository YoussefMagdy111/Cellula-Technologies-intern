# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# EDA Task by Youssef Abdelghany

# %%
data=pd.read_csv("/content/first inten project.csv")

# %%
data
# Out:
#       Booking_ID  number of adults  number of children  \
# 0       INN00001                 1                   1
# 1       INN00002                 1                   0
# 2       INN00003                 2                   1
# 3       INN00004                 1                   0
# 4       INN00005                 1                   0
# ...          ...               ...                 ...
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights  type of meal  \
# 0                             2                      5   Meal Plan 1
# 1                             1                      3  Not Selected
# 2                             1                      3   Meal Plan 1
# ...

# %%
## data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Booking_ID                36285 non-null  object
#  1   number of adults          36285 non-null  int64
#  2   number of children        36285 non-null  int64
#  3   number of weekend nights  36285 non-null  int64
#  4   number of week nights     36285 non-null  int64
#  5   type of meal              36285 non-null  object
#  6   car parking space         36285 non-null  int64
#  7   room type                 36285 non-null  object
#  8   lead time                 36285 non-null  int64
#  9   market segment type       36285 non-null  object
#  10  repeated                  36285 non-null  int64
#  11  P-C                       36285 non-null  int64
#  12  P-not-C                   36285 non-null  int64
# ...

# %%
## check null values
data.isnull().sum()
# Out:
# Booking_ID                  0
# number of adults            0
# number of children          0
# number of weekend nights    0
# number of week nights       0
# type of meal                0
# car parking space           0
# room type                   0
# lead time                   0
# market segment type         0
# repeated                    0
# P-C                         0
# P-not-C                     0
# average price               0
# special requests            0
# date of reservation         0
# booking status              0
# dtype: int64

# %%
### summary statisitics
data.describe()
# Out:
#        number of adults  number of children  number of weekend nights  \
# count      36285.000000        36285.000000              36285.000000
# mean           1.844839            0.105360                  0.810693
# std            0.518813            0.402704                  0.870590
# min            0.000000            0.000000                  0.000000
# 25%            2.000000            0.000000                  0.000000
# 50%            2.000000            0.000000                  1.000000
# 75%            2.000000            0.000000                  2.000000
# max            4.000000           10.000000                  7.000000
#
#        number of week nights  car parking space     lead time      repeated  \
# count           36285.000000       36285.000000  36285.000000  36285.000000
# mean                2.204602           0.030977     85.239851      0.025630
# std                 1.410946           0.173258     85.938796      0.158032
# ...

# %%
data.columns = data.columns.str.strip().str.lower().str.replace(' ', '_')
print(data.columns)
# Out:
# Index(['booking_id', 'number_of_adults', 'number_of_children',
#        'number_of_weekend_nights', 'number_of_week_nights', 'type_of_meal',
#        'car_parking_space', 'room_type', 'lead_time', 'market_segment_type',
#        'repeated', 'p-c', 'p-not-c', 'average_price', 'special_requests',
#        'date_of_reservation', 'booking_status'],
#       dtype='object')

# %%
numeric_cols = ['number_of_adults', 'number_of_children', 'lead_time', 'average_price']
for col in numeric_cols:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = data[(data[col] < lower) | (data[col] > upper)]
    print(f"\nOutliers in {col}:\n", outliers[[col]])
    ## checking for outliers
# Out:
# Outliers in number_of_adults:
#         number_of_adults
# 0                     1
# 1                     1
# 3                     1
# 4                     1
# 5                     1
# ...                 ...
# 36263                 1
# 36268                 1
# 36270                 3
# 36277                 1
# 36283                 3
#
# [10175 rows x 1 columns]
#
# Outliers in number_of_children:
#         number_of_children
# 0                       1
# 2                       1
# 6                       1
# 8                       1
# 32                      2
# ...                   ...
# 36221                   2
# 36227                   2
# 36231                   1
# 36249                   2
# 36269                   2
#
# [2702 rows x 1 columns]
#
# Outliers in lead_time:
#         lead_time
# 5            346
# 96           320
# 118          443
# 120          317
# 170          317
# ...          ...
# 36171        315
# 36178        386
# 36191        304
# ...

# %% [markdown]
# **i have some outliers but it make sense to the bussiness context , so no need to handle it **

# %%
import seaborn as sns
sns.histplot(data['average_price'], kde=True)
# Out:
# <Axes: xlabel='average_price', ylabel='Count'>

# %%
sns.boxplot(data['lead_time'])
# Out:
# <Axes: ylabel='lead_time'>

# %%
sns.countplot(data['booking_status'])
# Out:
# <Axes: xlabel='count', ylabel='booking_status'>

# %%
data["booking_status"].value_counts()
## i have imbalanced data
# Out:
# booking_status
# Not_Canceled    24396
# Canceled        11889
# Name: count, dtype: int64
